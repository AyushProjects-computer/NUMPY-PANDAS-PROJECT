# %%
import numpy as np
import matplotlib.pyplot as plt
salesdata=np.array([   [1, 12000, 15000, 18000],  # Product A
    [2, 10000, 14000, 17000],  # Product B
    [3, 20000, 22200, 16000]   # Product C
])
print("Shape",salesdata.shape)
print("DataType",salesdata.dtype)
salesvalue=salesdata[:,1:]
print(salesvalue)
maxcol=np.max(salesdata[:,1:],axis=1)
print(maxcol)
maxrow=np.max(salesdata[:,:],axis=0)
print(maxrow)
totalsalesproduct = np.sum(salesvalue, axis=1)
print("Total Sales per Product:", totalsalesproduct)
avgsalesperproduct=np.mean(salesvalue,axis=1)
print(avgsalesperproduct)
cumsumsalesproduct = np.cumsum(salesvalue, axis=1)
print("Cumulative Sales per Product:\n", cumsumsalesproduct)
monthlyavgsales=salesvalue/12
print(monthlyavgsales)
plt.figure(figsize=(8,5))
plt.plot(np.mean(cumsum_sales_product, axis=0))
plt.title("Average Cumulative Sales per Year")
plt.xlabel("Year Index (0=Year1)")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
# Out:
# Shape (3, 4)
# DataType int64
# [[12000 15000 18000]
#  [10000 14000 17000]
#  [20000 22200 16000]]
# [18000 17000 22200]
# [    3 20000 22200 18000]
# Total Sales per Product: [45000 41000 58200]
# [15000.         13666.66666667 19400.        ]
# Cumulative Sales per Product:
#  [[12000 27000 45000]
#  [10000 24000 41000]
#  [20000 42200 58200]]
# [[1000.         1250.         1500.        ]
#  [ 833.33333333 1166.66666667 1416.66666667]
#  [1666.66666667 1850.         1333.33333333]]
